# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt

# %%
(xtrain,ytrain),(xtest,ytest)=datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
ytest=ytest.reshape(-1,)
ytest
# Out:
# array([3, 8, 8, ..., 5, 1, 7], dtype=uint8)

# %%
classname=["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
def example(x,y,index):
    plt.figure(figsize=(15,2))
    plt.imshow(x[index])
    plt.xlabel(classname[y[index]])

# %%
example(xtest,ytest,55)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-5bcaf73339a1> in <cell line: 1>()
# ----> 1 testing = example(55)
#
# TypeError: example() missing 2 required positional arguments: 'y' and 'index'

# %%
xtrain=xtrain/255
xtest=xtest/255

# %%
from keras.layers import Input

model = models.Sequential([
    Input(shape=(32,32,3)),  # InputLayer'ı buraya ekleyin
    layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(2,2),

    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(2,2),

    layers.Flatten(),
    layers.Dense(64, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
history=model.fit(xtrain,ytrain,epochs=30, validation_data=(xtest,ytest))
# Out:
# Epoch 1/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 74s 46ms/step - accuracy: 0.3831 - loss: 1.6914 - val_accuracy: 0.5787 - val_loss: 1.1895
# Epoch 2/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 46ms/step - accuracy: 0.5941 - loss: 1.1556 - val_accuracy: 0.6324 - val_loss: 1.0605
# Epoch 3/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 70s 45ms/step - accuracy: 0.6471 - loss: 1.0089 - val_accuracy: 0.6532 - val_loss: 0.9971
# Epoch 4/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.6810 - loss: 0.9102 - val_accuracy: 0.6632 - val_loss: 0.9554
# Epoch 5/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 70s 45ms/step - accuracy: 0.7075 - loss: 0.8506 - val_accuracy: 0.6819 - val_loss: 0.9206
# Epoch 6/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 44ms/step - accuracy: 0.7215 - loss: 0.7823 - val_accuracy: 0.6889 - val_loss: 0.9206
# Epoch 7/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 69s 44ms/step - accuracy: 0.7498 - loss: 0.7240 - val_accuracy: 0.6882 - val_loss: 0.9254
# Epoch 8/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 44ms/step - accuracy: 0.7631 - loss: 0.6850 - val_accuracy: 0.6881 - val_loss: 0.9048
# Epoch 9/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 44ms/step - accuracy: 0.7710 - loss: 0.6480 - val_accuracy: 0.6977 - val_loss: 0.8937
# Epoch 10/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 44ms/step - accuracy: 0.7849 - loss: 0.6107 - val_accuracy: 0.6900 - val_loss: 0.9394
# Epoch 11/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 69s 44ms/step - accuracy: 0.7934 - loss: 0.5866 - val_accuracy: 0.6956 - val_loss: 0.9496
# Epoch 12/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.8086 - loss: 0.5433 - val_accuracy: 0.6943 - val_loss: 0.9728
# Epoch 13/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 44ms/step - accuracy: 0.8183 - loss: 0.5169 - val_accuracy: 0.6975 - val_loss: 0.9703
# Epoch 14/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 69s 44ms/step - accuracy: 0.8279 - loss: 0.4884 - val_accuracy: 0.7005 - val_loss: 1.0178
# Epoch 15/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 69s 44ms/step - accuracy: 0.8368 - loss: 0.4641 - val_accuracy: 0.6895 - val_loss: 1.0777
# Epoch 16/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 69s 44ms/step - accuracy: 0.8448 - loss: 0.4469 - val_accuracy: 0.6889 - val_loss: 1.0648
# Epoch 17/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.8555 - loss: 0.4175 - val_accuracy: 0.6944 - val_loss: 1.0793
# Epoch 18/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 45ms/step - accuracy: 0.8615 - loss: 0.3885 - val_accuracy: 0.6810 - val_loss: 1.1560
# Epoch 19/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.8642 - loss: 0.3789 - val_accuracy: 0.6833 - val_loss: 1.1744
# Epoch 20/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 44ms/step - accuracy: 0.8748 - loss: 0.3552 - val_accuracy: 0.6797 - val_loss: 1.2607
# Epoch 21/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.8820 - loss: 0.3352 - val_accuracy: 0.6769 - val_loss: 1.2960
# Epoch 22/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.8859 - loss: 0.3220 - val_accuracy: 0.6789 - val_loss: 1.2919
# Epoch 23/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.8918 - loss: 0.3052 - val_accuracy: 0.6804 - val_loss: 1.3309
# Epoch 24/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 45ms/step - accuracy: 0.8987 - loss: 0.2845 - val_accuracy: 0.6746 - val_loss: 1.4474
# Epoch 25/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.9067 - loss: 0.2672 - val_accuracy: 0.6833 - val_loss: 1.4612
# Epoch 26/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.9070 - loss: 0.2581 - val_accuracy: 0.6727 - val_loss: 1.5240
# Epoch 27/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.9115 - loss: 0.2476 - val_accuracy: 0.6615 - val_loss: 1.6120
# Epoch 28/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.9147 - loss: 0.2432 - val_accuracy: 0.6682 - val_loss: 1.6475
# Epoch 29/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.9210 - loss: 0.2223 - val_accuracy: 0.6743 - val_loss: 1.6495
# Epoch 30/30
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 45ms/step - accuracy: 0.9268 - loss: 0.2074 - val_accuracy: 0.6644 - val_loss: 1.7326

# %%
loss,acc= model.evaluate(xtest,ytest,verbose=False)

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'],color = "b",label= "Training Accuracy")
plt.plot(history.history["val_accuracy"], color = "r", label = "Validation Accuracy")
plt.legend(loc = "lower right")
plt.xlabel("Epoch", fontsize= 16)
plt.ylabel("Accuracy",fontsize = 16)
plt.ylim([min(plt.ylim()),1])
plt.title("Training and Test Performance Graph", fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Training and Test Performance Graph')

# %%
plt.figure(figsize= (20,5))
plt.subplot(1,2,2)
plt.plot(history.history["loss"],color= "b",label="Training Loss")
plt.plot(history.history["val_loss"],color="r",label="Validation Loss")
plt.legend(loc= "upper right")
plt.xlabel("Epoch",fontsize=16)
plt.ylabel("Loss",fontsize = 16)
plt.ylim([0,max(plt.ylim())])
plt.title("Training and Test Loss Graph",fontsize= 16)
plt.show()

# %%
ypred=model.predict(xtest)
ypred[:3]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
# array([[3.89188033e-04, 6.00185546e-09, 1.92524931e-05, 9.99326050e-01,
#         2.42954570e-07, 1.32219526e-07, 8.29801138e-05, 1.18088586e-07,
#         1.82054922e-04, 1.01120010e-08],
#        [4.48790843e-06, 2.36511711e-04, 3.59865566e-12, 4.35563608e-12,
#         3.29000094e-09, 2.14167788e-20, 2.41917533e-21, 2.06640832e-19,
#         9.99758959e-01, 2.96211091e-08],
#        [2.22873956e-01, 2.22395230e-02, 1.66607492e-07, 3.75487172e-04,
#         8.06749595e-05, 4.20360884e-04, 2.54587551e-08, 1.12410904e-04,
#         7.53191352e-01, 7.05982849e-04]], dtype=float32)

# %%
ypred1=[np.argmax(element) for element in ypred]
ypred1[:3]
# Out:
# [3, 8, 8]

# %%
y_true = [3, 8, 8, 0]

# Predicted classes
ypred1 = [3, 8, 1, 0]

# Printing the true and predicted classes
for true, pred in zip(y_true[:3], ypred1[:3]):
    print("True Class:", classname[true], "\tPredicted Class:", classname[pred])
# Out:
# True Class: cat 	Predicted Class: cat
# True Class: ship 	Predicted Class: ship
# True Class: ship 	Predicted Class: automobile
